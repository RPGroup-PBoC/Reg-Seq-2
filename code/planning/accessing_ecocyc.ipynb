# %% [markdown]
# # Accessing Ecocyc to get transcription start sites

# %% [markdown]
# (c) 2021 Tom Röschinger. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).

# %% [markdown]
# ***

# %%
using CSV, DataFrames, wgregseq, LightXML, HTTP

# %%
df = CSV.read("../../data/genes_MG1655.txt", DataFrame)
first(df, 5)
# Out:
# 5×11 DataFrame
#  Row │ Gene Name  Accession-1  Left-End-Position  Right-End-Position  Regulati ⋯
#      │ String31   String7?     Int64?             Int64?              Union{Mi ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ rfbC       b2038                  2109581             2110138  rfbACX / ⋯
#    2 │ yehE       b2112                  2192515             2192796  yehE
#    3 │ tmk        b1098                  1155124             1155765  pabC-mlt
#    4 │ yadG       b0127                   142779              143705  yadGH
#    5 │ sthA       b3962                  4159390             4160790  sthA     ⋯
#                                                                7 columns omitted

# %%
names(df)
# Out:
# 11-element Vector{String}:
#  "Gene Name"
#  "Accession-1"
#  "Left-End-Position"
#  "Right-End-Position"
#  "Regulation - transcription units of gene"
#  "Object ID"
#  "Transcription units - promoter of operon"
#  "Transcription units - binding sites"
#  "Transcription units - regulators of operon"
#  "Regulation - direct regulators of gene"
#  "Regulation - transcription factor regulators of gene"

# %%
gold_standards = [
    "rspA",
    "araA",
    "araB",
    "znuC",
    "znuB",
    "xylA",
    "xylF",
    "dicC",
    "relE",
    "relB",
    "ftsK",
    "znuA",
    "lacI",
    "marR",
    "dgoR",
    "ompR",
    "dicA",
    "araC"
]
xml = wgregseq.design.get_ecocyc("araC")[1];

# %%
# get the root element
xroot = root(xml)  # an instance of XMLElement
# print its name
ces = xroot["Transcription-Unit"][1];

# %%
ces = xroot["Transcription-Unit"]

for e1 in ces
    components = get_elements_by_tagname(e1, "component")
    es = [get_elements_by_tagname(component, "Promoter") for component in components]
    if length(es) > 0
        for element in es
            if length(element) > 0
                att = element[1]["absolute-plus-1-pos"]
                if length(att) > 0 
                    println(content(att[1]))
                end
            end
        end
    end
end

# %%
xroot
# Out:
# <ptools-xml ptools-version="25.0" xml:base="http://BioCyc.org/apixml?fn=transcription-units-of-gene%26id=ECOLI:EG10054%26detail=FULL">
#   <metadata>
#     <url>http://BioCyc.org/</url>
#     <service_name>apixml</service_name>
#     <query>fn=transcription-units-of-gene&amp;id=ECOLI:EG10054&amp;detail=FULL</query>
#     <num_results>1</num_results>
#     <PGDB orgid="ECOLI" version="25.1">
#       <species datatype="string">Escherichia coli</species>
#       <strain datatype="string">K-12 substr. MG1655</strain>
#       <dblink>
#         <dblink-db>NCBI-TAXONOMY-DB</dblink-db>
#         <dblink-oid>511145</dblink-oid>
#         <dblink-relationship>unification</dblink-relationship>
#         <dblink-URL>http://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?mode=Info&amp;id=511145</dblink-URL>
#       </dblink>
#     </PGDB>
#   </metadata>
#   <Transcription-Unit ID="ECOLI:TU00003" orgid="ECOLI" frameid="TU00003" detail="full">
#     <replicon>
#       <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#     </replicon>
#     <synonym datatype="string">OP00004</synonym>
#     <citation>
#       <Publication ID="ECOLI:PUB-6262769" orgid="ECOLI" frameid="PUB-6262769" detail="full">
#         <source datatype="string">Proc Natl Acad Sci U S A 78(2);752-6</source>
#         <title datatype="string">Mechanism of araC autoregulation and the domains of two overlapping promoters, Pc and PBAD, in the L-arabinose regulatory region of Escherichia coli.</title>
#         <year datatype="integer">1981</year>
#         <author datatype="string">Lee NL</author>
#         <author datatype="string">Gielow WO</author>
#         <author datatype="string">Wallace RG</author>
#         <pubmed-id datatype="string">6262769</pubmed-id>
#       </Publication>
#     </citation>
#     <citation>
#       <Publication ID="ECOLI:PUB-6377308" orgid="ECOLI" frameid="PUB-6377308" detail="full">
#         <source datatype="string">Proc Natl Acad Sci U S A 81(13);4120-4</source>
#         <title datatype="string">Regulation of the araC gene of Escherichia coli: catabolite repression, autoregulation, and effect on araBAD expression.</title>
#         <year datatype="integer">1984</year>
#         <author datatype="string">Miyada CG</author>
#         <author datatype="string">Stoltzfus L</author>
#         <author datatype="string">Wilcox G</author>
#         <pubmed-id datatype="string">6377308</pubmed-id>
#       </Publication>
#     </citation>
#     <common-name datatype="string">araC</common-name>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS00004" orgid="ECOLI" frameid="BS00004" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="integer">70118</abs-center-pos>
#         <citation>
#           <Publication ID="ECOLI:PUB-2962192" orgid="ECOLI" frameid="PUB-2962192" detail="full">
#             <source datatype="string">Proc Natl Acad Sci U S A 84(24);8814-8</source>
#             <title datatype="string">Arabinose-induced binding of AraC protein to araI2 activates the araBAD operon promoter.</title>
#             <year datatype="integer">1987</year>
#             <author datatype="string">Lee N</author>
#             <author datatype="string">Francklyn C</author>
#             <author datatype="string">Hamilton EP</author>
#             <pubmed-id datatype="string">2962192</pubmed-id>
#           </Publication>
#         </citation>
#         <citation>
#           <Publication ID="ECOLI:PUB-3041410" orgid="ECOLI" frameid="PUB-3041410" detail="full">
#             <source datatype="string">Proc Natl Acad Sci U S A 85(15);5444-8</source>
#             <title datatype="string">Alternative DNA loops regulate the arabinose operon in Escherichia coli.</title>
#             <year datatype="integer">1988</year>
#             <author datatype="string">Huo L</author>
#             <author datatype="string">Martin KJ</author>
#             <author datatype="string">Schleif R</author>
#             <pubmed-id datatype="string">3041410</pubmed-id>
#           </Publication>
#         </citation>
#         <citation>
#           <Publication ID="ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677" detail="full">
#             <source datatype="string">J Mol Biol 264(4);667-74</source>
#             <title datatype="string">How AraC interacts specifically with its target DNAs.</title>
#             <year datatype="integer">1996</year>
#             <author datatype="string">Niland P</author>
#             <author datatype="string">Huhne R</author>
#             <author datatype="string">Muller-Hill B</author>
#             <pubmed-id datatype="string">8980677</pubmed-id>
#           </Publication>
#         </citation>
#         <evidence>
#           <Evidence-Code ID="ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" detail="full" class="true">
#             <parent>
#               <Evidence-Code resource="getxml?ECOLI:EV-COMP-HINF" orgid="ECOLI" frameid="EV-COMP-HINF" class="true"/>
#             </parent>
#             <comment datatype="string">Human inference based on similarity to consensus sequences</comment>
#             <common-name datatype="string">A person inferred or reviewed a computer inference of sequence function based on similarity to a consensus sequence.</common-name>
#           </Evidence-Code>
#           <Publication ID="ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145" detail="full">
#             <source datatype="string">Microbiol Mol Biol Rev 61(4);393-410</source>
#             <title datatype="string">Arac/XylS family of transcriptional regulators.</title>
#             <year datatype="integer">1997</year>
#             <author datatype="string">Gallegos MT</author>
#             <author datatype="string">Schleif R</author>
#             <author datatype="string">Bairoch A</author>
#             <author datatype="string">Hofmann K</author>
#             <author datatype="string">Ramos JL</author>
#             <pubmed-id datatype="string">9409145</pubmed-id>
#           </Publication>
#         </evidence>
#         <evidence>
#           <Evidence-Code ID="ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" detail="full" class="true">
#             <parent>
#               <Evidence-Code resource="getxml?ECOLI:EV-EXP-NUC-ACID-BINDING" orgid="ECOLI" frameid="EV-EXP-NUC-ACID-BINDING" class="true"/>
#             </parent>
#             <common-name datatype="string">Binding of purified proteins</common-name>
#           </Evidence-Code>
#           <Publication ID="ECOLI:PUB-8516313" orgid="ECOLI" frameid="PUB-8516313" detail="full">
#             <source datatype="string">Proc Natl Acad Sci U S A 90(12);5638-42</source>
#             <title datatype="string">Functional domains of the AraC protein.</title>
#             <year datatype="integer">1993</year>
#             <author datatype="string">Bustos SA</author>
#             <author datatype="string">Schleif RF</author>
#             <pubmed-id datatype="string">8516313</pubmed-id>
#           </Publication>
#         </evidence>
#         <evidence>
#           <Evidence-Code ID="ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" detail="full" class="true">
#             <parent>
#               <Evidence-Code resource="getxml?ECOLI:EV-EXP-IMP" orgid="ECOLI" frameid="EV-EXP-IMP" class="true"/>
#             </parent>
#             <comment datatype="string">A cis-mutation in the DNA sequence of the transcription-factor binding site interferes with the operation of the regulatory function. This is considered  strong evidence for the existence and functional role of the DNA binding site.</comment>
#             <common-name datatype="string">Site mutation</common-name>
#           </Evidence-Code>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" class="true"/>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation ID="ECOLI:REG0-4766" orgid="ECOLI" frameid="REG0-4766" detail="low">
#             <parent>
#               <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#             </parent>
#             <mode datatype="string">+</mode>
#             <regulated-entity>
#               <Promoter ID="ECOLI:PM00004" orgid="ECOLI" frameid="PM00004" detail="full">
#                 <replicon>
#                   <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#                 </replicon>
#                 <transcription-direction datatype="string">+</transcription-direction>
#                 <absolute-plus-1-pos datatype="integer" units="base pairs">70223</absolute-plus-1-pos>
#                 <binds-sigma-factor>
#                   <Protein resource="getxml?ECOLI:RPOD-MONOMER" orgid="ECOLI" frameid="RPOD-MONOMER"/>
#                 </binds-sigma-factor>
#                 <evidence>
#                   <Evidence-Code ID="ECOLI:EV-COMP-HINF" orgid="ECOLI" frameid="EV-COMP-HINF" detail="full" class="true">
#                     <parent>
#                       <Evidence-Code resource="getxml?ECOLI:EV-COMP" orgid="ECOLI" frameid="EV-COMP" class="true"/>
#                     </parent>
#                     <comment datatype="string">Human inference.  A curator or author inferred this assertion after review of one or more possible types
# of computational evidence such as sequence similarity, recognized motifs or consensus sequence, etc.
# When the inference was made by a computer in an automated fashion, use EV-AINF.</comment>
#                     <common-name datatype="string">Inferred by a human based on computational evidence</common-name>
#                   </Evidence-Code>
#                   <Publication ID="ECOLI:PUB-3279415" orgid="ECOLI" frameid="PUB-3279415" detail="full">
#                     <source datatype="string">Proc Natl Acad Sci U S A 85(6);1749-53</source>
#                     <title datatype="string">Three binding sites for AraC protein are required for autoregulation of araC in Escherichia coli.</title>
#                     <year datatype="integer">1988</year>
#                     <author datatype="string">Hamilton EP</author>
#                     <author datatype="string">Lee N</author>
#                     <pubmed-id datatype="string">3279415</pubmed-id>
#                   </Publication>
#                 </evidence>
#                 <citation>
#                   <Publication ID="ECOLI:PUB-7019009" orgid="ECOLI" frameid="PUB-7019009" detail="full">
#                     <source datatype="string">Gene 12(3-4);179-90</source>
#                     <title datatype="string">The araC gene of Escherichia coli: transcriptional and translational start-points and complete nucleotide sequence.</title>
#                     <year datatype="integer">1980</year>
#                     <author datatype="string">Wallace RG</author>
#                     <author datatype="string">Lee N</author>
#                     <author datatype="string">Fowler AV</author>
#                     <pubmed-id datatype="string">7019009</pubmed-id>
#                   </Publication>
#                 </citation>
#                 <citation>
#                   <Publication resource="#ECOLI:PUB-3279415" orgid="ECOLI" frameid="PUB-3279415"/>
#                 </citation>
#                 <evidence>
#                   <Evidence-Code ID="ECOLI:EV-EXP-IDA-TRANSCRIPTION-INIT-MAPPING" orgid="ECOLI" frameid="EV-EXP-IDA-TRANSCRIPTION-INIT-MAPPING" detail="full" class="true">
#                     <parent>
#                       <Evidence-Code resource="getxml?ECOLI:EV-EXP-IDA" orgid="ECOLI" frameid="EV-EXP-IDA" class="true"/>
#                     </parent>
#                     <comment datatype="string">The transcription start site is identified by primer extension.</comment>
#                     <common-name datatype="string">Transcription initiation mapping</common-name>
#                   </Evidence-Code>
#                   <Publication resource="#ECOLI:PUB-7019009" orgid="ECOLI" frameid="PUB-7019009"/>
#                 </evidence>
#                 <evidence>
#                   <Evidence-Code ID="ECOLI:EV-COMP-HINF-POSITIONAL-IDENTIFICATION" orgid="ECOLI" frameid="EV-COMP-HINF-POSITIONAL-IDENTIFICATION" detail="full" class="true">
#                     <parent>
#                       <Evidence-Code resource="#ECOLI:EV-COMP-HINF" orgid="ECOLI" frameid="EV-COMP-HINF" class="true"/>
#                     </parent>
#                     <comment datatype="string">A person inferred, or reviewed a computer inference of, promoter position relative to the -10 and -35 boxes. </comment>
#                     <common-name datatype="string">Human inference of promoter position</common-name>
#                   </Evidence-Code>
#                   <Publication resource="#ECOLI:PUB-3279415" orgid="ECOLI" frameid="PUB-3279415"/>
#                 </evidence>
#                 <common-name datatype="string">araCp</common-name>
#                 <component-of>
#                   <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#                 </component-of>
#                 <minus-10-left datatype="integer">70209</minus-10-left>
#                 <minus-10-right datatype="integer">70214</minus-10-right>
#                 <minus-35-left datatype="integer">70186</minus-35-left>
#                 <minus-35-right datatype="integer">70191</minus-35-right>
#                 <regulated-by>
#                   <Regulation ID="ECOLI:REG0-12387" orgid="ECOLI" frameid="REG0-12387" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:MONOMER0-165" orgid="ECOLI" frameid="MONOMER0-165"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-12386" orgid="ECOLI" frameid="REG0-12386" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:MONOMER0-165" orgid="ECOLI" frameid="MONOMER0-165"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4772" orgid="ECOLI" frameid="REG0-4772" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:PC00003" orgid="ECOLI" frameid="PC00003"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4771" orgid="ECOLI" frameid="REG0-4771" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4770" orgid="ECOLI" frameid="REG0-4770" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4769" orgid="ECOLI" frameid="REG0-4769" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:PC00003" orgid="ECOLI" frameid="PC00003"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4768" orgid="ECOLI" frameid="REG0-4768" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">+</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX0-226" orgid="ECOLI" frameid="CPLX0-226"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4767" orgid="ECOLI" frameid="REG0-4767" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">+</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation resource="#ECOLI:REG0-4766" orgid="ECOLI" frameid="REG0-4766"/>
#                 </regulated-by>
#               </Promoter>
#             </regulated-entity>
#             <regulator>
#               <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#             </regulator>
#           </Regulation>
#           <Regulation ID="ECOLI:REG0-4760" orgid="ECOLI" frameid="REG0-4760" detail="low">
#             <parent>
#               <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#             </parent>
#             <mode datatype="string">+</mode>
#             <regulated-entity>
#               <Promoter ID="ECOLI:PM00003" orgid="ECOLI" frameid="PM00003" detail="full">
#                 <replicon>
#                   <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#                 </replicon>
#                 <synonym datatype="string">araBAD</synonym>
#                 <absolute-plus-1-pos datatype="integer" units="base pairs">70075</absolute-plus-1-pos>
#                 <binds-sigma-factor>
#                   <Protein resource="getxml?ECOLI:RPOD-MONOMER" orgid="ECOLI" frameid="RPOD-MONOMER"/>
#                 </binds-sigma-factor>
#                 <evidence>
#                   <Evidence-Code ID="ECOLI:EV-COMP-AINF" orgid="ECOLI" frameid="EV-COMP-AINF" detail="full" class="true">
#                     <parent>
#                       <Evidence-Code resource="getxml?ECOLI:EV-COMP" orgid="ECOLI" frameid="EV-COMP" class="true"/>
#                     </parent>
#                     <comment datatype="string">Automated inference.  A computer inferred this assertion through one of many possible methods such as
# sequence similarity, recognized motifs or consensus sequence, etc.  When a person made the inference
# from computational evidence, use EV-HINF</comment>
#                     <common-name datatype="string">Inferred computationally without human oversight</common-name>
#                   </Evidence-Code>
#                   <Publication ID="ECOLI:PUB-14529615" orgid="ECOLI" frameid="PUB-14529615" detail="full">
#                     <source datatype="string">J Mol Biol 333(2);261-78</source>
#                     <title datatype="string">Sigma70 promoters in Escherichia coli: specific transcription in dense regions of overlapping promoter-like signals.</title>
#                     <year datatype="integer">2003</year>
#                     <author datatype="string">Huerta AM</author>
#                     <author datatype="string">Collado-Vides J</author>
#                     <pubmed-id datatype="string">14529615</pubmed-id>
#                   </Publication>
#                 </evidence>
#                 <citation>
#                   <Publication ID="ECOLI:PUB-8479900" orgid="ECOLI" frameid="PUB-8479900" detail="full">
#                     <source datatype="string">Nucleic Acids Res 21(7);1507-16</source>
#                     <title datatype="string">Compilation of E. coli mRNA promoter sequences.</title>
#                     <year datatype="integer">1993</year>
#                     <author datatype="string">Lisser S</author>
#                     <author datatype="string">Margalit H</author>
#                     <pubmed-id datatype="string">8479900</pubmed-id>
#                   </Publication>
#                 </citation>
#                 <citation>
#                   <Publication ID="ECOLI:PUB-189315" orgid="ECOLI" frameid="PUB-189315" detail="full">
#                     <source datatype="string">Proc Natl Acad Sci U S A 74(1);49-53</source>
#                     <title datatype="string">Nucleotide sequence of the 5' end of araBAD operon messenger RNA in Escherichia coli B/r.</title>
#                     <year datatype="integer">1977</year>
#                     <author datatype="string">Lee N</author>
#                     <author datatype="string">Carbon J</author>
#                     <pubmed-id datatype="string">189315</pubmed-id>
#                   </Publication>
#                 </citation>
#                 <citation>
#                   <Publication ID="ECOLI:PUB-357433" orgid="ECOLI" frameid="PUB-357433" detail="full">
#                     <source datatype="string">J Biol Chem 253(19);6931-3</source>
#                     <title datatype="string">Nucleotide sequence of the L-arabinose regulatory region of Escherichia coli K12.</title>
#                     <year datatype="integer">1978</year>
#                     <author datatype="string">Smith BR</author>
#                     <author datatype="string">Schleif R</author>
#                     <pubmed-id datatype="string">357433</pubmed-id>
#                   </Publication>
#                 </citation>
#                 <evidence>
#                   <Evidence-Code resource="#ECOLI:EV-EXP-IDA-TRANSCRIPTION-INIT-MAPPING" orgid="ECOLI" frameid="EV-EXP-IDA-TRANSCRIPTION-INIT-MAPPING" class="true"/>
#                   <Publication resource="#ECOLI:PUB-189315" orgid="ECOLI" frameid="PUB-189315"/>
#                 </evidence>
#                 <common-name datatype="string">araBp</common-name>
#                 <component-of>
#                   <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#                 </component-of>
#                 <minus-10-left datatype="integer">70084</minus-10-left>
#                 <minus-10-right datatype="integer">70089</minus-10-right>
#                 <minus-35-left datatype="integer">70108</minus-35-left>
#                 <minus-35-right datatype="integer">70113</minus-35-right>
#                 <regulated-by>
#                   <Regulation ID="ECOLI:REG0-4765" orgid="ECOLI" frameid="REG0-4765" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:PC00003" orgid="ECOLI" frameid="PC00003"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4764" orgid="ECOLI" frameid="REG0-4764" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:PC00003" orgid="ECOLI" frameid="PC00003"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4763" orgid="ECOLI" frameid="REG0-4763" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4762" orgid="ECOLI" frameid="REG0-4762" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">-</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation ID="ECOLI:REG0-4761" orgid="ECOLI" frameid="REG0-4761" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">+</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX0-226" orgid="ECOLI" frameid="CPLX0-226"/>
#                     </regulator>
#                   </Regulation>
#                   <Regulation resource="#ECOLI:REG0-4760" orgid="ECOLI" frameid="REG0-4760"/>
#                   <Regulation ID="ECOLI:REG0-4759" orgid="ECOLI" frameid="REG0-4759" detail="low">
#                     <parent>
#                       <Regulation resource="getxml?ECOLI:Transcription-Factor-Binding" orgid="ECOLI" frameid="Transcription-Factor-Binding" class="true"/>
#                     </parent>
#                     <mode datatype="string">+</mode>
#                     <regulated-entity>
#                       <Promoter resource="#ECOLI:PM00003" orgid="ECOLI" frameid="PM00003"/>
#                     </regulated-entity>
#                     <regulator>
#                       <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#                     </regulator>
#                   </Regulation>
#                 </regulated-by>
#               </Promoter>
#             </regulated-entity>
#             <regulator>
#               <Protein resource="getxml?ECOLI:CPLX-172" orgid="ECOLI" frameid="CPLX-172"/>
#             </regulator>
#           </Regulation>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <Promoter resource="#ECOLI:PM00004" orgid="ECOLI" frameid="PM00004"/>
#     </component>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS00007" orgid="ECOLI" frameid="BS00007" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="integer">70139</abs-center-pos>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" class="true"/>
#           <Publication resource="#ECOLI:PUB-8516313" orgid="ECOLI" frameid="PUB-8516313"/>
#         </evidence>
#         <citation>
#           <Publication ID="ECOLI:PUB-2643114" orgid="ECOLI" frameid="PUB-2643114" detail="full">
#             <source datatype="string">Proc Natl Acad Sci U S A 86(2);476-80</source>
#             <title datatype="string">In vivo DNA loops in araCBAD: size limits and helical repeat.</title>
#             <year datatype="integer">1989</year>
#             <author datatype="string">Lee DH</author>
#             <author datatype="string">Schleif RF</author>
#             <pubmed-id datatype="string">2643114</pubmed-id>
#           </Publication>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-6262769" orgid="ECOLI" frameid="PUB-6262769"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </citation>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" class="true"/>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" class="true"/>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation resource="#ECOLI:REG0-4769" orgid="ECOLI" frameid="REG0-4769"/>
#           <Regulation resource="#ECOLI:REG0-4767" orgid="ECOLI" frameid="REG0-4767"/>
#           <Regulation resource="#ECOLI:REG0-4764" orgid="ECOLI" frameid="REG0-4764"/>
#           <Regulation resource="#ECOLI:REG0-4759" orgid="ECOLI" frameid="REG0-4759"/>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS0-4502" orgid="ECOLI" frameid="BS0-4502" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="integer">70192</abs-center-pos>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" class="true"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </evidence>
#         <citation>
#           <Publication ID="ECOLI:PUB-1560456" orgid="ECOLI" frameid="PUB-1560456" detail="full">
#             <source datatype="string">J Mol Biol 224(2);335-41</source>
#             <title datatype="string">Repression of the araBAD promoter from araO1.</title>
#             <year datatype="integer">1992</year>
#             <author datatype="string">Lee DH</author>
#             <author datatype="string">Huo L</author>
#             <author datatype="string">Schleif R</author>
#             <pubmed-id datatype="string">1560456</pubmed-id>
#           </Publication>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-6262769" orgid="ECOLI" frameid="PUB-6262769"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </citation>
#         <evidence>
#           <Evidence-Code ID="ECOLI:EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" detail="full" class="true">
#             <parent>
#               <Evidence-Code resource="getxml?ECOLI:EV-EXP-NUC-ACID-BINDING" orgid="ECOLI" frameid="EV-EXP-NUC-ACID-BINDING" class="true"/>
#             </parent>
#             <comment datatype="string">There exists physical evidence of the binding of cellular extracts containing
# a regulatory protein to its DNA binding site.  This can be either by
# footprinting or mobility shift assays.</comment>
#             <common-name datatype="string">Binding of cellular extracts</common-name>
#           </Evidence-Code>
#           <Publication resource="#ECOLI:PUB-1560456" orgid="ECOLI" frameid="PUB-1560456"/>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation resource="#ECOLI:REG0-4770" orgid="ECOLI" frameid="REG0-4770"/>
#           <Regulation resource="#ECOLI:REG0-4763" orgid="ECOLI" frameid="REG0-4763"/>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS0-4503" orgid="ECOLI" frameid="BS0-4503" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="integer">70213</abs-center-pos>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" class="true"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </evidence>
#         <citation>
#           <Publication resource="#ECOLI:PUB-1560456" orgid="ECOLI" frameid="PUB-1560456"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-6262769" orgid="ECOLI" frameid="PUB-6262769"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </citation>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" class="true"/>
#           <Publication resource="#ECOLI:PUB-1560456" orgid="ECOLI" frameid="PUB-1560456"/>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation resource="#ECOLI:REG0-4771" orgid="ECOLI" frameid="REG0-4771"/>
#           <Regulation resource="#ECOLI:REG0-4762" orgid="ECOLI" frameid="REG0-4762"/>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS00006" orgid="ECOLI" frameid="BS00006" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="integer">70350</abs-center-pos>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-CELLULAR-EXTRACTS" class="true"/>
#           <Publication resource="#ECOLI:PUB-3041410" orgid="ECOLI" frameid="PUB-3041410"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </evidence>
#         <citation>
#           <Publication resource="#ECOLI:PUB-9409145" orgid="ECOLI" frameid="PUB-9409145"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-6262769" orgid="ECOLI" frameid="PUB-6262769"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-3041410" orgid="ECOLI" frameid="PUB-3041410"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-2643114" orgid="ECOLI" frameid="PUB-2643114"/>
#         </citation>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-8980677" orgid="ECOLI" frameid="PUB-8980677"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" class="true"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" class="true"/>
#           <Publication ID="ECOLI:PUB-9600836" orgid="ECOLI" frameid="PUB-9600836" detail="full">
#             <source datatype="string">J Mol Biol 278(3);529-38</source>
#             <title datatype="string">Apo-AraC actively seeks to loop.</title>
#             <year datatype="integer">1998</year>
#             <author datatype="string">Seabold RR</author>
#             <author datatype="string">Schleif RF</author>
#             <pubmed-id datatype="string">9600836</pubmed-id>
#           </Publication>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation resource="#ECOLI:REG0-4772" orgid="ECOLI" frameid="REG0-4772"/>
#           <Regulation resource="#ECOLI:REG0-4765" orgid="ECOLI" frameid="REG0-4765"/>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <DNA-Binding-Site ID="ECOLI:BS00005" orgid="ECOLI" frameid="BS00005" detail="full">
#         <replicon>
#           <Genetic-Element resource="getxml?ECOLI:COLI-K12" orgid="ECOLI" frameid="COLI-K12"/>
#         </replicon>
#         <abs-center-pos datatype="float">70168.5</abs-center-pos>
#         <citation>
#           <Publication resource="#ECOLI:PUB-3279415" orgid="ECOLI" frameid="PUB-3279415"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-2962192" orgid="ECOLI" frameid="PUB-2962192"/>
#         </citation>
#         <citation>
#           <Publication resource="#ECOLI:PUB-3041410" orgid="ECOLI" frameid="PUB-3041410"/>
#         </citation>
#         <citation>
#           <Publication ID="ECOLI:PUB-2521619" orgid="ECOLI" frameid="PUB-2521619" detail="full">
#             <source datatype="string">J Bacteriol 171(2);1178-84</source>
#             <title datatype="string">Effect of mutations in the cyclic AMP receptor protein-binding site on araBAD and araC expression.</title>
#             <year datatype="integer">1989</year>
#             <author datatype="string">Stoltzfus L</author>
#             <author datatype="string">Wilcox G</author>
#             <pubmed-id datatype="string">2521619</pubmed-id>
#           </Publication>
#         </citation>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IMP-SITE-MUTATION" orgid="ECOLI" frameid="EV-EXP-IMP-SITE-MUTATION" class="true"/>
#           <Publication resource="#ECOLI:PUB-2521619" orgid="ECOLI" frameid="PUB-2521619"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-COMP-HINF-SIMILAR-TO-CONSENSUS" orgid="ECOLI" frameid="EV-COMP-HINF-SIMILAR-TO-CONSENSUS" class="true"/>
#           <Publication resource="#ECOLI:PUB-2521619" orgid="ECOLI" frameid="PUB-2521619"/>
#         </evidence>
#         <evidence>
#           <Evidence-Code resource="#ECOLI:EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" orgid="ECOLI" frameid="EV-EXP-IDA-BINDING-OF-PURIFIED-PROTEINS" class="true"/>
#           <Publication ID="ECOLI:PUB-9440505" orgid="ECOLI" frameid="PUB-9440505" detail="full">
#             <source datatype="string">J Bacteriol 180(2);195-200</source>
#             <title datatype="string">Catabolite gene activator protein mutations affecting activity of the araBAD promoter.</title>
#             <year datatype="integer">1998</year>
#             <author datatype="string">Zhang X</author>
#             <author datatype="string">Schleif R</author>
#             <pubmed-id datatype="string">9440505</pubmed-id>
#           </Publication>
#         </evidence>
#         <component-of>
#           <Transcription-Unit resource="#ECOLI:TU00003" orgid="ECOLI" frameid="TU00003"/>
#           <Transcription-Unit resource="getxml?ECOLI:TU00214" orgid="ECOLI" frameid="TU00214"/>
#         </component-of>
#         <involved-in-regulation>
#           <Regulation resource="#ECOLI:REG0-4768" orgid="ECOLI" frameid="REG0-4768"/>
#           <Regulation resource="#ECOLI:REG0-4761" orgid="ECOLI" frameid="REG0-4761"/>
#         </involved-in-regulation>
#       </DNA-Binding-Site>
#     </component>
#     <component>
#       <Gene resource="getxml?ECOLI:EG10054" orgid="ECOLI" frameid="EG10054"/>
#     </component>
#   </Transcription-Unit>
# </ptools-xml>

# %%
s = open("../../data/var_genes.txt") do file
    read(file, String)
end
var_genes = split(s, '\n')[1:end-1];

# %%
for gene in var_genes
    if length(df[df[!, "Gene Name"] .== gene, "Regulation - direct regulators of gene"]) < 1
        println(gene)
    end
end
# Out:
# ygaU
# pckA
# lpdA
# yeeX
# prr
# yjiY
# fliY
# gyrI
# gpmI
# ydbC
# ydjN
# yifE
# ynhG
# ygfY
# mtnN
# typA
# yhcB
# trpG
# ybgF
# ybiC
# yjjK
# yhcH
# nfnB
# csiD
# yaiE
# ybdH
# ybiS
# yqiC
# hldD
# ycbL
# acuI
# coaB
# yraP
# phnB
# yfiQ
