# %%
using CSV, DataFrames, wgregseq, CairoMakie, Statistics, BioSequences

# %%
df_LB = CSV.read("../../../data/LB_barcodes.csv", DataFrame);

# %%
_df_LB = df_LB[df_LB.name .== "rspAp", :]

fig = Figure(resolution=(1200, 300))

ax1 = Axis(fig[1, 1], xlabel="DNA counts", ylabel="RNA_counts")
scatter!(ax1, _df.ct_0, _df.ct_1)

ax2 = Axis(fig[1, 2])
fig
